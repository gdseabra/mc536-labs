# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# ## Tarefa 1

# %%
import pandas as pd
import requests

data1 = requests.get('https://api.covid19api.com/countries').json()
print(data1)
# Out:
# [{'Country': 'American Samoa', 'Slug': 'american-samoa', 'ISO2': 'AS'}, {'Country': 'Belize', 'Slug': 'belize', 'ISO2': 'BZ'}, {'Country': 'Cook Islands', 'Slug': 'cook-islands', 'ISO2': 'CK'}, {'Country': 'Ecuador', 'Slug': 'ecuador', 'ISO2': 'EC'}, {'Country': 'Indonesia', 'Slug': 'indonesia', 'ISO2': 'ID'}, {'Country': 'Isle of Man', 'Slug': 'isle-of-man', 'ISO2': 'IM'}, {'Country': 'Mozambique', 'Slug': 'mozambique', 'ISO2': 'MZ'}, {'Country': 'United States of America', 'Slug': 'united-states', 'ISO2': 'US'}, {'Country': 'ALA Aland Islands', 'Slug': 'ala-aland-islands', 'ISO2': 'AX'}, {'Country': 'Croatia', 'Slug': 'croatia', 'ISO2': 'HR'}, {'Country': 'Grenada', 'Slug': 'grenada', 'ISO2': 'GD'}, {'Country': 'Mayotte', 'Slug': 'mayotte', 'ISO2': 'YT'}, {'Country': "Côte d'Ivoire", 'Slug': 'cote-divoire', 'ISO2': 'CI'}, {'Country': 'Libya', 'Slug': 'libya', 'ISO2': 'LY'}, {'Country': 'Niger', 'Slug': 'niger', 'ISO2': 'NE'}, {'Country': 'Niue', 'Slug': 'niue', 'ISO2': 'NU'}, {'Country': 'Cuba', 'Slug': 'cuba', 'ISO2': 'CU'}, {'Country': 'Lao PDR', 'Slug': 'lao-pdr', 'ISO2': 'LA'}, {'Country': 'Poland', 'Slug': 'poland', 'ISO2': 'PL'}, {'Country': 'Saint-Martin (French part)', 'Slug': 'saint-martin-french-part', 'ISO2': 'MF'}, {'Country': 'Slovakia', 'Slug': 'slovakia', 'ISO2': 'SK'}, {'Country': 'Chile', 'Slug': 'chile', 'ISO2': 'CL'}, {'Country': 'Eritrea', 'Slug': 'eritrea', 'ISO2': 'ER'}, {'Country': 'Antarctica', 'Slug': 'antarctica', 'ISO2': 'AQ'}, {'Country': 'Marshall Islands', 'Slug': 'marshall-islands', 'ISO2': 'MH'}, {'Country': 'Syrian Arab Republic (Syria)', 'Slug': 'syria', 'ISO2': 'SY'}, {'Country': 'United Arab Emirates', 'Slug': 'united-arab-emirates', 'ISO2': 'AE'}, {'Country': 'Dominica', 'Slug': 'dominica', 'ISO2': 'DM'}, {'Country': 'Samoa', 'Slug': 'samoa', 'ISO2': 'WS'}, {'Country': 'Somalia', 'Slug': 'somalia', 'ISO2': 'SO'}, {'Country': 'Taiwan, Republic of China', 'Slug': 'taiwan', 'ISO2': 'TW'}, {'Country': 'Tajikistan', 'Slug': 'tajikistan', 'ISO2': 'TJ'}, {'Country': 'Turks and Caicos Islands', 'Slug': 'turks-and-caicos-islands', 'ISO2': 'TC'}, {'Country': 'Botswana', 'Slug': 'botswana', 'ISO2': 'BW'}, {'Country': 'Ghana', 'Slug': 'ghana', 'ISO2': 'GH'}, {'Country': 'Jersey', 'Slug': 'jersey', 'ISO2': 'JE'}, {'Country': 'New Zealand', 'Slug': 'new-zealand', 'ISO2': 'NZ'}, {'Country': 'Peru', 'Slug': 'peru', 'ISO2': 'PE'}, {'Country': 'Nepal', 'Slug': 'nepal', 'ISO2': 'NP'}, {'Country': 'Venezuela (Bolivarian Republic)', 'Slug': 'venezuela', 'ISO2': 'VE'}, {'Country': 'Algeria', 'Slug': 'algeria', 'ISO2': 'DZ'}, {'Country': 'Uzbekistan', 'Slug': 'uzbekistan', 'ISO2': 'UZ'}, {'Country': 'Wallis and Futuna Islands', 'Slug': 'wallis-and-futuna-islands', 'ISO2': 'WF'}, {'Country': 'Falkland Islands (Malvinas)', 'Slug': 'falkland-islands-malvinas', 'ISO2': 'FK'}, {'Country': 'Hungary', 'Slug': 'hungary', 'ISO2': 'HU'}, {'Country': 'Solomon Islands', 'Slug': 'solomon-islands', 'ISO2': 'SB'}, {'Country': 'Bulgaria', 'Slug': 'bulgaria', 'ISO2': 'BG'}, {'Country': 'Papua New Guinea', 'Slug': 'papua-new-guinea', 'ISO2': 'PG'}, {'Country': 'Turkey', 'Slug': 'turkey', 'ISO2': 'TR'}, {'Country': 'Zambia', 'Slug': 'zambia', 'ISO2': 'ZM'}, {'Country': 'Fiji', 'Slug': 'fiji', 'ISO2': 'FJ'}, {'Country': 'Martinique', 'Slug': 'martinique', 'ISO2': 'MQ'}, {'Country': 'Mongolia', 'Slug': 'mongolia', 'ISO2': 'MN'}, {'Country': 'Palau', 'Slug': 'palau', 'ISO2': 'PW'}, {'Country': 'Russian Federation', 'Slug': 'russia', 'ISO2': 'RU'}, {'Country': 'Senegal', 'Slug': 'senegal', 'ISO2': 'SN'}, {'Country': 'Serbia', 'Slug': 'serbia', 'ISO2': 'RS'}, {'Country': 'Anguilla', 'Slug': 'anguilla', 'ISO2': 'AI'}, {'Country': 'Argentina', 'Slug': 'argentina', 'ISO2': 'AR'}, {'Country': 'Cayman Islands', 'Slug': 'cayman-islands', 'ISO2': 'KY'}, {'Country': 'Vanuatu', 'Slug': 'vanuatu', 'ISO2': 'VU'}, {'Country': 'Virgin Islands, US', 'Slug': 'virgin-islands', 'ISO2': 'VI'}, {'Country': 'Namibia', 'Slug': 'namibia', 'ISO2': 'NA'}, {' ...

# %%
data2 = requests.get('https://webapi.nhtsa.gov/api/SafetyRatings/modelyear/2013/make/Acura/model/rdx?format=xml')
print(data2.content)
# Out:
# b'\xef\xbb\xbf<Response xmlns:i="http://www.w3.org/2001/XMLSchema-instance" xmlns="NHTSA/webapi/types"><Count>2</Count><Message>Results returned successfully</Message><Results><CrashTestedVehicle xmlns=""><VehicleId>7731</VehicleId><VehicleDescription>2013 Acura RDX SUV 4WD</VehicleDescription></CrashTestedVehicle><CrashTestedVehicle xmlns=""><VehicleId>7520</VehicleId><VehicleDescription>2013 Acura RDX SUV FWD</VehicleDescription></CrashTestedVehicle></Results></Response>'

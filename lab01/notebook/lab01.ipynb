# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# ## Tarefa 1

# %%
import pandas as pd
import requests

data1 = requests.get('https://api.covid19api.com/live/country/south-africa/status/confirmed').json()
print(data1)
# Out:
# [{'ID': '2fb4b60d-efcd-47c3-b4d9-44c58328cdd0', 'Country': 'South Africa', 'CountryCode': 'ZA', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '-30.56', 'Lon': '22.94', 'Confirmed': 1877143, 'Deaths': 59406, 'Recovered': 1675827, 'Active': 141910, 'Date': '2021-06-25T00:00:00Z'}, {'ID': 'd2970361-321a-4491-a19d-825121a91cb3', 'Country': 'South Africa', 'CountryCode': 'ZA', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '-30.56', 'Lon': '22.94', 'Confirmed': 1895905, 'Deaths': 59621, 'Recovered': 1690380, 'Active': 145904, 'Date': '2021-06-26T00:00:00Z'}, {'ID': 'ba4eb46d-b2c3-4e00-ac00-e3ab029c2779', 'Country': 'South Africa', 'CountryCode': 'ZA', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '-30.56', 'Lon': '22.94', 'Confirmed': 1913861, 'Deaths': 59778, 'Recovered': 1702070, 'Active': 152013, 'Date': '2021-06-27T00:00:00Z'}, {'ID': 'b3b4b69c-a97c-4274-ab9a-38b3e9f2ef92', 'Country': 'South Africa', 'CountryCode': 'ZA', 'Province': '', 'City': '', 'CityCode': '', 'Lat':
# ...

# %%
data2 = requests.get('https://webapi.nhtsa.gov/api/SafetyRatings/modelyear/2013/make/Acura/model/rdx?format=xml')
print(data2.content)
# Out:
# b'\xef\xbb\xbf<Response xmlns:i="http://www.w3.org/2001/XMLSchema-instance" xmlns="NHTSA/webapi/types"><Count>2</Count><Message>Results returned successfully</Message><Results><CrashTestedVehicle xmlns=""><VehicleId>7731</VehicleId><VehicleDescription>2013 Acura RDX SUV 4WD</VehicleDescription></CrashTestedVehicle><CrashTestedVehicle xmlns=""><VehicleId>7520</VehicleId><VehicleDescription>2013 Acura RDX SUV FWD</VehicleDescription></CrashTestedVehicle></Results></Response>'
